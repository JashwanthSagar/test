# %%
boy=input("enter your name=")
girl=input("enter your name=")
length=len(boy)+len(girl)
count=0
for i in range(len(boy)):
    for j in range(len(girl)):
        if boy[i]==girl[j]:
            count+=2
            break;
total=length-count
g=['f','l','a','m','e','s']
count=0
comp=0
final=[]
n=-1
i=6
while (1):
    if comp==5:
        break;
    elif count==total-1:
        count=0
        let=g[n]
        final.append(let)
        g.remove(g[n])
        comp=comp+1
        i=i-1
    else:
        n=((n+1) % i)
        count+=1

l=[item for item in g if item not in final]
dic={
      "f":"friends",
      "l":"love",
      "a":"akramasambandham"
    ,
      "m":"marriage",
      "e":"emeny",
      "s":"slibings"
    }
print(dic[l[0]])
# Out:
# enter your name= saikarthik
# enter your name= rider
# marriage
